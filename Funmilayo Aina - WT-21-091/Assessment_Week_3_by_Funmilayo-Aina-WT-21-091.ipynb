# %% [markdown]
# ## This Program is to Translate a Complain from one language to another
#
# ### This project is the work of Funmilayo Aina - WT/21/091

# %%
import requests
import json

# %%
Customer_Complaints = {}
team_id = {101,102,103,104}
languages = {'en': 'english', 'af': 'afrikaans', 'sq': 'albanian', 'am': 'amharic', 'ar': 'arabic',
             'hy': 'armenian', 'az': 'azerbaijani', 'eu': 'basque', 'be': 'belarusian', 'bn': 'bengali',
             'bs': 'bosnian', 'bg': 'bulgarian', 'ca': 'catalan', 'ceb': 'cebuano', 'ny': 'chichewa',
             'zh-cn': 'chinese (simplified)', 'zh-tw': 'chinese (traditional)', 'co': 'corsican',
             'hr': 'croatian', 'cs': 'czech', 'da': 'danish', 'nl': 'dutch', 'eo': 'esperanto',
             'et': 'estonian', 'tl': 'filipino', 'fi': 'finnish', 'fr': 'french', 'fy': 'frisian', 
             'gl': 'galician', 'ka': 'georgian', 'de': 'german', 'el': 'greek', 'gu': 'gujarati', 
             'ht': 'haitian creole', 'ha': 'hausa', 'haw': 'hawaiian', 'iw': 'hebrew', 'hi': 'hindi', 
             'hmn': 'hmong', 'hu': 'hungarian', 'is': 'icelandic', 'ig': 'igbo', 'id': 'indonesian', 
             'ga': 'irish', 'it': 'italian', 'ja': 'japanese', 'jw': 'javanese', 'kn': 'kannada', 
             'kk': 'kazakh', 'km': 'khmer', 'ko': 'korean', 'ku': 'kurdish (kurmanji)', 'ky': 'kyrgyz', 
             'lo': 'lao', 'la': 'latin', 'lv': 'latvian', 'lt': 'lithuanian', 'lb': 'luxembourgish', 
             'mk': 'macedonian', 'mg': 'malagasy', 'ms': 'malay', 'ml': 'malayalam', 'mt': 'maltese', 
             'mi': 'maori', 'mr': 'marathi', 'mn': 'mongolian', 'my': 'myanmar (burmese)', 'ne': 'nepali', 
             'no': 'norwegian', 'ps': 'pashto', 'fa': 'persian', 'pl': 'polish', 'pt': 'portuguese', 
             'pa': 'punjabi', 'ro': 'romanian', 'ru': 'russian', 'sm': 'samoan', 'gd': 'scots gaelic', 
             'sr': 'serbian', 'st': 'sesotho', 'sn': 'shona', 'sd': 'sindhi', 'si': 'sinhala', 'sk': 'slovak', 
             'sl': 'slovenian', 'so': 'somali', 'es': 'spanish', 'su': 'sundanese', 'sw': 'swahili', 
             'sv': 'swedish', 'tg': 'tajik', 'ta': 'tamil', 'te': 'telugu', 'th': 'thai', 'tr': 'turkish', 
             'uk': 'ukrainian', 'ur': 'urdu', 'uz': 'uzbek', 'vi': 'vietnamese', 'cy': 'welsh', 'xh': 'xhosa', 
             'yi': 'yiddish', 'yo': 'yoruba', 'zu': 'zulu', 'fil': 'Filipino', 'he': 'Hebrew'}

# %%
def Customers():
    id_main = len(Customer_Complaints.values())+1
    if Customer_Complaints:
        name = input("What is your name?\n")
        complaints=input(f"{name}, Kindly enter your complain...\n")
        if complaints in Customer_Complaints.keys():
            print("Complaint already exist")
            complaints=input("Kindly enter another complaint ... \n")
        else:
            for record in Customer_Complaints.values():
                if complaints in record.values():
                    complaints=print('Complain already exist, please enter another complain!\n')
                else:
                    Customer_Complaints[complaints]={"ID":id_main, "Customer_name":name, "Complaint":complaints}
                    Customer_Complaints.values()
                    print("Thank you, your complain will be attended to.")
                    print('========================')
                    break
    else:
        
        name = input("What is your name?\n")
        complaints=input(f"{name}, Kindly enter your complain...\n")
        Customer_Complaints[complaints]={"ID":id_main, "Customer_name":name, "Complaint":complaints}
        print("Thank you, your complain will be attended to.")
        print('========================')

# %%
def team():
    id=int(input("Enter your Team ID\n"))
    if id in team_id:
        print(f"Welcome Team ID: {id}")
        print('========================')
        question = input("Do you want to translate a complain? Y or N...\n").upper()
        if question == 'Y':
            print('========================')
            print(Customer_Complaints.values())
            print('========================')
            select_id = int(input("select --ID-- of complaint to translate...\n"))
            for records in Customer_Complaints.values():
                if select_id == records["ID"]:
                    print(records)
                    complain = records["Complaint"]
                    detected = detect(complain)
                    lang = detected["data"]["detections"][0][0]["language"]
                    for key, value in languages.items():
                        if lang == key:
                            detect_ = value
                            lang_detect = detect_.capitalize()
                            print("=============================================")
                            print(f"The complain was written in {lang_detect}")
                            print("=============================================")
                            print([i for i in languages.values()])
                            print("=============================================")
                            print("")
                            trans_lang = input("Select from list above, the language to be translated to\n")
                            print("")
                            for i, j in languages.items():
                                if trans_lang.lower() == j:
                                    resp = translate(complain, i, lang)
                                    print(f"====Find the translation from {lang_detect} to {trans_lang.capitalize()} below====")
                                    print(resp["data"]["translations"][0]['translatedText'])
                                    print("=============================================")
                                    print(f"Have a good day!!!")
                                    print("=============================================")
                            
                                    
                else:
                    continue
        else:
            print("Okay, Bye...!")
            
    else:
        print("Sorry, you do not have team access!!!")

# %%
def detect(complain):
    
    url = "https://google-translate1.p.rapidapi.com/language/translate/v2/detect"

    payload = f"q={complain}"
    headers = {
        'content-type': "application/x-www-form-urlencoded",
        'accept-encoding': "application/gzip",
        'x-rapidapi-key': "ea7da142a9msh1db51587da1204ep17552fjsn4d2b1b38fda9",
        'x-rapidapi-host': "google-translate1.p.rapidapi.com"
        }

    response = requests.request("POST", url, data=payload, headers=headers)
    resp = json.loads(response.text)
    return resp

# %%
def translate(complain,lang_target,lang_src):

    url = "https://google-translate1.p.rapidapi.com/language/translate/v2"

    payload = f"q={complain}&target={lang_target}&source={lang_src}"
    headers = {
        'content-type': "application/x-www-form-urlencoded",
        'accept-encoding': "application/gzip",
        'x-rapidapi-key': "ea7da142a9msh1db51587da1204ep17552fjsn4d2b1b38fda9",
        'x-rapidapi-host': "google-translate1.p.rapidapi.com"
        }

    response = requests.request("POST", url, data=payload, headers=headers)
    resp = json.loads(response.text)
    return resp

# %%
def main():
    runtime = 1
    while runtime:
        print('Welcome to Customer Complaints Dashboard')
        print("!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!")
        checker = int(input('Enter 0 for Customer, 1 for Staff, and 2 to quit:\n'))
        if checker == 0:
            submit = input("Do you want to submit a complain? Y or N\n").upper()
            if submit not in ("Y","N"):
                print("Wrong entry!!! Kindly enter Y or N")
                if submit == 'Y':
                    
                    Customers()
                    
                else:
                    print("Thank you, have a good day!!!")
            else:
                if submit == 'Y':
                    Customers()
                else:
                    print("Thank you, have a good day!!!")
        elif checker == 1:
            team()
            break
        else:
            print("Thank you!!!")
            break

# %%
main()
# Out:
# Welcome to Customer Complaints Dashboard
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Enter 0 for Customer, 1 for Staff, and 2 to quit:
# 0
# Do you want to submit a complain? Y or N
# Y
# What is your name?
# Funmi
# Funmi, Kindly enter your complain...
# The expiry date of the item is too early
# Thank you, your complain will be attended to.
# ...
# Welcome to Customer Complaints Dashboard
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Enter 0 for Customer, 1 for Staff, and 2 to quit:
# 0
# Do you want to submit a complain? Y or N
# Y
# What is your name?
# Uchenna
# Uchenna, Kindly enter your complain...
# The lid for the pot is oversize
# Thank you, your complain will be attended to.
# ...
# Welcome to Customer Complaints Dashboard
# !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# Enter 0 for Customer, 1 for Staff, and 2 to quit:
# 1
# Enter your Team ID
# 101
# Welcome Team ID: 101
# ...
# Do you want to translate a complain? Y or N...
# Y
# ...
